# %% [markdown]
# # RAG Student Assistant

# %% [markdown]
# ## Ingestion (Web Scraping)

# %%
# Scrap data from the official website (Presentation)
import requests 
from bs4 import BeautifulSoup

url = "https://www.esi-sba.dz/fr/index.php/presentation/"

response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

docs = []
presentation = ""

paragraphs = soup.find_all("p")[:-3]
for p in paragraphs:
    presentation+='\n' + p.get_text()
    

span_elements = soup.find_all("span", class_="gdlr-core-icon-list-content")[:4]
spans = ""
for s in span_elements:
    spans+='\n' + s.get_text()

presentation+=spans
print(presentation)

docs.append({
    "url": url,
    "content": presentation
})
# Out:
# L’Ecole Supérieure en Informatique 08 mai 1945 de Sidi Bel Abbes est un établissement universitaire public, placé sous la tutelle du Ministère de l’Enseignement Supérieur et de la Recherche Scientifique, créé par le décret exécutif n° 14-232 du 25 août 2014.
# L’école assure des formations de graduation, post-graduation et de formation continue.
# Elle décerne le diplôme d’ingénieur d’état en informatique, pouvant être doublé d’un master, ainsi que le diplôme de docteur en informatique.
# Elle abrite également un Laboratoire de Recherche en Informatique (LabRI) qui intègre une majorité des enseignants de l’école, renforçant l’excellence des formations délivrées par l’école, et développant de nouvelles méthodes et technologies pour les problématiques les plus actuelles. Ce lien entre la formation et la recherche garantit la mise sur le marché du travail d’ingénieurs performant, compétant et, à jour des nouvelles technologies.
# ...

# %%
# Scrap data from the official website (Director's word)
url = "https://www.esi-sba.dz/fr/index.php/mot-du-directeur/"

response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

mot_directeur = ""
paragraph_elements = soup.find_all("p")[:-3]
paragraph = paragraph_elements[0].get_text()

for p in paragraph_elements[1:]:
    paragraph+='\n' + p.get_text()
    
docs.append({
    "url": url,
    "content": paragraph  
})

print(docs[1])
# Out:
# {'url': 'https://www.esi-sba.dz/fr/index.php/mot-du-directeur/', 'content': 'Chers collaborateurs, chers étudiants\nEn ce début d’année universitaire, je tiens à m’adresser à vous tous pour vous souhaiter une année pleine de labeur et de satisfaction d’une part, et vous faire partager mes convictions de rendre notre École un site privilégié de formation de qualité d’autre part.\nL’École, dans ses ambitions, devrait se hisser au pôle d’excellence qui est inhérent au développement de la recherche et la promotion de son staff et bien sûr à l’émancipation de ses infrastructures. L’école Bénéficiera d’un environnement scientifique et technologique de très haut niveau. Elle compte offrir une formation au contact de la recherche et de l’innovation. Attentifs aux avancées technologiques et aux attentes des entreprises, l’offre de formation sera évolutive et s’adaptera aux exigences industrielles.\nÀ mes étudiants, je dis «Bienvenue à l’école ». Être dans une École supérieure ou à l’Universit
# ...

# %%
# Scrap data from the official website (School Missions)
url = "https://www.esi-sba.dz/fr/index.php/missions-et-objectifs/"

response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

paragraph_elements = soup.find_all("p")
heading_elements = soup.find_all("h3")

div_left = soup.find_all("div", class_="gdlr-core-column-service-content")[0]
div_right= soup.find_all("div", class_="gdlr-core-column-service-content")[1]

list_elements = div_left.find_all("li")
list_elements_2 = div_right.find_all("li")

missions = heading_elements[0].get_text() + '\n' + paragraph_elements[0].get_text() + '\n' + heading_elements[1].get_text()

for li in list_elements:
    missions += '\n' + li.get_text()

missions+='\n' + heading_elements[2].get_text() # <<=== HERE!!!!!!!!!!!

for li in list_elements_2:
    missions += '\n' + li.get_text()

print(missions)

docs.append({
    "url": url,
    "content": missions
})
# Out:
# Missions et Objectifs
# Dans le cadre du service public d’enseignement supérieur, l’école assure des missions de formation supérieure et des missions de recherche scientifique et de développement technologique.
# En matière de formation supérieure, l'école a pour missions fondamentales dans son domaine de vocation :
# d’assurer la formation des cadres (Ingénieur, Master, Magister, Docteur en sciences et Docteur en troisième cycle –Système LMD–).
# d’initier les étudiants aux méthodes de recherche et d’assurer la formation pour la recherche,
# de contribuer à la production et à la diffusion du savoir et des connaissances ; à leur acquisition et leur
# développement,
# de participer à la formation continue.
# En matière de recherche scientifique et de développement technologique l'école a pour mission fondamentale :
# de contribuer à l’effort national de recherche scientifique et de développement technologique,
# de promouvoir le développement des sciences et des techniques,
# ...

# %%
# Scrap data from the official website (Organigram)
url = "https://www.esi-sba.dz/fr/index.php/organigramme/"

response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")
organigramme = ""

heading_elements = soup.find_all("h3")
paragraph_elements = soup.find_all("p")
span_elements = soup.find_all("span")
div = soup.find_all("div", class_="gdlr-core-text-box-item-content")
li_elements = soup.find_all("li")

organigramme+=heading_elements[0].get_text() + '\n' + paragraph_elements[0].get_text() + '\n' + span_elements[6].get_text() + '\n' + span_elements[8].get_text() + '\n' + span_elements[10].get_text() + '\n' + heading_elements[1].get_text()+ '\n' + paragraph_elements[1].get_text() + div[2].get_text() + heading_elements[2].get_text() + '\n' + li_elements[157].get_text() + '\n' + li_elements[158].get_text() + '\n' + li_elements[159].get_text() + '\n' + heading_elements[3].get_text() + '\n' + li_elements[160].get_text() + '\n' + li_elements[161].get_text() + '\n' + li_elements[162].get_text() + '\n' + heading_elements[4].get_text() + '\n' + li_elements[163].get_text() + '\n' + li_elements[164].get_text() + '\n' + li_elements[165].get_text() + heading_elements[5].get_text() + '\n' + li_elements[166].get_text() + '\n' + li_elements[167].get_text() + '\n' + heading_elements[6].get_text() + '\n' + li_elements[168].get_text() + '\n' + li_elements[169].get_text() + '\n' + li_elements[170].get_text() + heading_elements[7].get_text() + '\n' + li_elements[171].get_text() + '\n' + li_elements[172].get_text()

docs.append({
    "url": url,
    "content": organigramme
})

# %%
# Scrap data from the official website (FAQ)
url = "https://www.esi-sba.dz/fr/index.php/faq/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
h4_elements = soup.find_all("h4")
div = soup.find_all("div", class_="gdlr-core-text-box-item-content")
paragraph_elements = soup.find_all("p")
li_elements = soup.find_all("li")[161:166]

faq = heading_elements[1].get_text()
faq+=div[0].get_text() + h4_elements[0].get_text() + '\n' + paragraph_elements[0].get_text() + '\n' + li_elements[0].get_text()

for li in li_elements[1:]:
    faq+='\n'+li.get_text()

faq+='\n\n' + h4_elements[1].get_text() + paragraph_elements[1].get_text()
li_elements = soup.find_all("li")[166:170]
for li in li_elements:
    faq+='\n'+li.get_text()


faq+='\n\n' + h4_elements[2].get_text() + paragraph_elements[2].get_text()
li_elements = soup.find_all("li")[170:172]
for li in li_elements:
    faq+='\n'+li.get_text()
    
faq+='\n\n' + h4_elements[3].get_text() + soup.find_all("li")[172].get_text()

faq+= '\n' + h4_elements[4].get_text() + '\n' + paragraph_elements[4].get_text()

faq+='\n\n' + h4_elements[5].get_text() + '\n' + paragraph_elements[5].get_text()
faq+='\n'+paragraph_elements[6].get_text() + '\n'+paragraph_elements[7].get_text() + '\n'+paragraph_elements[8].get_text()

faq+= '\n\n' + h4_elements[6].get_text() + '\n'+paragraph_elements[9].get_text()
faq+= '\n\n' + h4_elements[7].get_text() + '\n'+paragraph_elements[10].get_text()

faq+='\n\n' + h4_elements[8].get_text() + '\n' + paragraph_elements[11].get_text()
li_elements = soup.find_all("li")[173:189]
for li in li_elements:
    faq+='\n'+li.get_text()
faq+='\n' + paragraph_elements[12].get_text() + '\n' + paragraph_elements[13].get_text()

faq+='\n\n' + h4_elements[9].get_text() + '\n' + paragraph_elements[14].get_text()

faq+='\n\n' + h4_elements[10].get_text() + '\n' + paragraph_elements[15].get_text() + '\n' + paragraph_elements[18].get_text()
li_elements = soup.find_all("li")[190:193]
for li in li_elements:
    faq+='\n'+li.get_text()

faq+='\n\n' + h4_elements[11].get_text() + '\n' + paragraph_elements[22].get_text()

faq+='\n\n' + h4_elements[12].get_text() + '\n' + paragraph_elements[23].get_text() + '\n' + paragraph_elements[24].get_text()

faq+='\n\n' + h4_elements[13].get_text() + '\n' + paragraph_elements[25].get_text() + '\n' + paragraph_elements[26].get_text()

faq+='\n\n' + h4_elements[14].get_text()
li_elements = soup.find_all("li")[194:196]
for li in li_elements:
    faq+='\n'+li.get_text()

faq+='\n\n' + h4_elements[15].get_text() + '\n' + paragraph_elements[27].get_text()

faq+='\n\n' + h4_elements[16].get_text() + '\n' + paragraph_elements[28].get_text()
li_elements = soup.find_all("li")[196:198]
for li in li_elements:
    faq+='\n'+li.get_text()

faq+='\n\n' + h4_elements[17].get_text() + '\n' + paragraph_elements[29].get_text()
li_elements = soup.find_all("li")[199:200]
for li in li_elements:
    faq+='\n'+li.get_text()

docs.append({
    "url": url,
    "content": faq
})
print(faq)
# Out:
# Pourquoi choisir l’ESI-SBA ?
# Une école de performance pour une formation d’excellence qui pousse les étudiants à donner le meilleur d’eux même et à développer le maximum de leur potentiel.
# Cursus et programmes de formation modernes et évolutifs.
# Encadrement de rang magistral, professeurs et maîtres de conférences ; nombreux jeunes docteurs motivés et hautement qualifiés.
# Un parcours bi-diplômant (Ingéniorat + Master).
# Partenariat avec le Secteur socio-économique, les écoles nationales, les universités et à l’international.
# Accompagnement personnalisé des élèves ingénieurs dans leur progression, leurs stages et leur projet professionnel.
# Nombreux laboratoires pédagogiques et de recherche.
# Bibliothèque centrale et espace multimédia.
# Intervenants externes spécialisés pour assurer des enseignements, des conférences ou des ateliers pratiques, à tous les niveaux de formation.
# Laboratoire de recherche en informatique (LABRI-SBA)
# Des équipements modernes.
# ...

# %%
# Scrap data from the official website (Conseil Administration)
url = "https://www.esi-sba.dz/fr/index.php/conseil-dadministration/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
paragraph_elements = soup.find_all("p")
div_elements = soup.find_all("div", class_="gdlr-core-icon-list-content-wrap")

conseil = ""
conseil+=heading_elements[0].get_text() + '\n' + paragraph_elements[0].get_text() + '\n' + paragraph_elements[1].get_text()
for div in div_elements[:12]:
    conseil+='\n' + div.get_text()

conseil+='\n\n' + paragraph_elements[2].get_text() + '\n\n' + heading_elements[1].get_text()
for div in div_elements[12:27]:
    conseil+='\n' + div.get_text()

conseil+='\n\n' + heading_elements[2].get_text()
for div in div_elements[27:45]:
    conseil+='\n'+div.get_text()
    
docs.append({
    "url": url,
    "content": conseil
})

# %%
# Scrap data from the official website (Conseil Scientifique)
url = "https://www.esi-sba.dz/fr/index.php/conseil-scientifique/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
paragraph_elements = soup.find_all("p")
div_elements = soup.find_all("div", class_="gdlr-core-icon-list-content-wrap")

conseil = heading_elements[0].get_text()
conseil += '\n' + paragraph_elements[0].get_text() + '\n' + paragraph_elements[1].get_text()
for div in div_elements[:11]:
    conseil+= '\n' + div.get_text()

conseil += '\n\n' + paragraph_elements[2].get_text() + '\n\n' + heading_elements[1].get_text()
for div in div_elements[11:19]:
    conseil+= '\n' + div.get_text()

conseil+='\n\n' + heading_elements[2].get_text()   
for div in div_elements[19:37]:
    conseil+= '\n' + div.get_text()

docs.append({
    "url": url,
    "content": conseil
})

# %%
# Scrap data from the official website (Comité éthique)
url = "https://www.esi-sba.dz/fr/index.php/conseil-de-lesi-sba/comite-local-dethique-et-de-deontologie/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
paragraph_elements = soup.find_all("p")
div_elements = soup.find_all("div", class_="gdlr-core-icon-list-content-wrap")

comite = heading_elements[0].get_text() + '\n' + heading_elements[1].get_text() + '\n' + paragraph_elements[0].get_text()
comite+= '\n\n' + heading_elements[2].get_text() + '\n' + div_elements[0].get_text()

for heading in heading_elements[3:10]:
    comite+='\n' + heading.get_text()
    
comite+='\n' + div_elements[1].get_text()

comite+= '\n' + heading_elements[10].get_text() + '\n' + paragraph_elements[2].get_text()
comite+= '\n' + heading_elements[11].get_text() + '\n' + paragraph_elements[3].get_text()
comite+= '\n' + heading_elements[12].get_text() + '\n' + paragraph_elements[4].get_text()

for p in paragraph_elements[5:12]:
    comite+= '\n' + p.get_text()
    
comite+= '\n\n' + heading_elements[13].get_text() + '\n' + paragraph_elements[13].get_text() + '\n' + paragraph_elements[14].get_text() + '\n' + paragraph_elements[15].get_text()
comite+= """
M. MALKI Mimoun, Professeur en Informatique, Président
M. RAHMOUN Abdellatif, Professeur en Informatique, Membre
M. BENSLIMANE Sidi Mohamed, Professeur en Informatique, Membre
M. KESKES Nabil, Professeur en Informatique, Membre
Mme. KIES Nadia, Professeur en Anglais, Membre
M. AMAR BENSABER Djamel, MCA en Informatique, Membre
"""

docs.append({
    "url": url,
    "content": comite
})

# %%
# Scrap data from the official website (Comité éthique)
url = "https://www.esi-sba.dz/fr/index.php/annuaire/annuaire-enseignant/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
div_elements = soup.find_all("div", class_="gdlr-core-personnel-list-title gdlr-core-title-font")
div_titles = soup.find_all("div", class_="gdlr-core-personnel-list-position gdlr-core-info-font")

enseignants = heading_elements[0].get_text()


for i in range(len(div_elements)):
    enseignants+= '\n' + div_elements[i].get_text() + " " + div_titles[i].get_text()

docs.append({
    "url": url,
    "content": enseignants
})

# %%
# Scrap data from the official website (Personnel)
url = "https://www.esi-sba.dz/fr/index.php/annuaire/annuaire-du-personnel/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
phones = soup.find_all("div", class_="kingster-personnel-info-list kingster-type-phone")
titles = soup.find_all("p")

personnel = heading_elements[0].get_text()
personnel+= '\n' + heading_elements[1].get_text() + " " + " " + "s.benslimane@esi-sba.dz" + " " + phones[0].get_text() + " " + titles[0].get_text()
personnel+= '\n' + heading_elements[2].get_text() + " " + " " + "i.benouazzani@esi-sba.dz" +  " " + titles[1].get_text()
personnel+= '\n' + heading_elements[3].get_text() + " " + " " + "m.malki@esi-sba.dz" +  " " + titles[2].get_text()
personnel+= '\n' + heading_elements[4].get_text() + " " + " " + "d.amarbensaber@esi-sba.dz" + " " + phones[1].get_text() + " " + titles[4].get_text()
personnel+= '\n' + heading_elements[5].get_text() + " " + " " + "m.bedjaoui@esi-sba.dz" + " " + phones[2].get_text() + " " + titles[3].get_text()
personnel+= '\n' + heading_elements[6].get_text() + " " + " " + "m.aced@esi-sba.dz" +  " " + titles[5].get_text()

docs.append({
    "url": url,
    "content": personnel
})

# %%
# Scrap data from the official website (Missions)
url = "https://www.esi-sba.dz/fr/index.php/missions-formation/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
div_elements = soup.find_all("div", class_="gdlr-core-icon-list-content-wrap")
paragraph_elements = soup.find_all("p")

missions = heading_elements[0].get_text() + '\n' + heading_elements[1].get_text() 
for div in div_elements[:6]:
    missions+= '\n' + div.get_text()

missions+= '\n' + paragraph_elements[0].get_text()

docs.append({
    "url": url,
    "content": missions
}
)

# %%
# Shéma de formation
url = "https://www.esi-sba.dz/fr/index.php/formation/schema-de-formation/"
formation = """
Shéma de formation:
1- Classe Préparatoire (02ans)
    1-1 1ére année classe préparatoire
    1-2 2éme année classe préparatoire
2- Concours
3- Second cycle (02 ans)
    3-1 Tronc commun du second cycle
    3-2 Ingénieur: Système d’information et web (02ans), Ingénieur: Ingénierie des Systèmes Informatiques (02ans), Ingénieur: Intelligence artificielle et sciences de données (02ans)
    3-3 Master: Systéme d’information et web (+200heures) *, Master: Ingénierie des systèmes informatique (+200heures) *, Master: Intelligence artificielle et sciences de données(+200heures) *
4- Troisième cycle (03 ans) Doctorat
"""

docs.append({
    "url": url,
    "content": formation
})

# %%
import pandas as pd

url = "https://www.esi-sba.dz/fr/index.php/graduation/classe-preparatoire/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
tr_elements = soup.find_all("tr")

prepa = heading_elements[0].get_text() + '\n' + heading_elements[1].get_text() + '\n' + "Semestre 1, 15 semaines"

heading = tr_elements[0].get_text().strip().replace('\n', ", ")
for tr in tr_elements[:18]:
    prepa+= '\n' + tr.get_text().strip().replace('\n', ", ")

prepa+='\n\n' + "Répartition des enseignements semestre 2, 15 semaines"
for tr in tr_elements[18:36]:
    prepa+= '\n' + tr.get_text().strip().replace('\n', ", ")

prepa+='\n\n' + heading_elements[2].get_text()+ '\n' + "Semestre 1, 15 semaines"
for tr in tr_elements[36:56]:
    prepa+= '\n' + tr.get_text().strip().replace('\n', ", ")
    
prepa+='\n\n' + "Répartition des enseignements semestre 2, 15 semaines"
for tr in tr_elements[56:75]:
    prepa+= '\n' + tr.get_text().strip().replace('\n', ", ")

docs.append({
    "url": url,
    "content": prepa
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/formation/schema-de-formation/tronc-commun-du-second-cycle/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
heading_elements_4 = soup.find_all("h4")
paragraph_elements = soup.find_all("p")
tr_elements = soup.find_all("tr")

tronc = heading_elements[0].get_text() + '\n' + heading_elements[1].get_text() + '\n' + heading_elements_4[0].get_text() + '\n' + paragraph_elements[0].get_text() + '\n' + "Semestre 1:"
for tr in tr_elements[:19]:
    tronc+= '\n' + tr.get_text().strip().replace('\n', ", ")

tronc+='\n\n' + "Semestre 2:"
for tr in tr_elements[19:38]:
    tronc+= '\n' + tr.get_text().strip().replace('\n', ", ")

docs.append({
    "url": url,
    "content": tronc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/specialite-ingenierie-des-systemes-informatiques-isi/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
heading_elements_4 = soup.find_all("h4")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")
tr_elements = soup.find_all("tr")

isi = heading_elements[0].get_text() + '\n' + heading_elements_4[1].get_text() + paragraph_elements[2].get_text() + '\n' + paragraph_elements[3].get_text()
isi+= '\n\n' + heading_elements_4[2].get_text()
for p in paragraph_elements[4:7]:
    isi+='\n' + p.get_text()

isi+=ul_elements[34].get_text() + '\n' + paragraph_elements[7].get_text() + ul_elements[35].get_text() + '\n' + heading_elements_4[3].get_text()
isi+='\n' + paragraph_elements[8].get_text() + '\n' + paragraph_elements[9].get_text() + ul_elements[36].get_text() + '\n' + heading_elements[1].get_text() + '\n' + "Semestre 3, 15 semaines" + '\n'
for tr in tr_elements[:20]:
    isi+= '\n' + tr.get_text().strip().replace('\n', ", ")

isi+= '\n\n' + "Semestre 4, 15 semaines"
for tr in tr_elements[20:39]:
    isi+= '\n' + tr.get_text().strip().replace('\n', ", ")

isi+='\n\n' + heading_elements[2].get_text() + '\n' + "Semestre 5, 15 semaines"
for tr in tr_elements[39:58]:
    isi+= '\n' + tr.get_text().strip().replace('\n', ", ")

isi+='\n\n' + "Semestre 6, 15 semaines"
for tr in tr_elements[58:77]:
    isi+= '\n' + tr.get_text().strip().replace('\n', ", ")

docs.append({
    "url": url,
    "content": isi
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/specialite-systemes-dinformation-et-web-siw/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
heading_elements_4 = soup.find_all("h4")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")
tr_elements = soup.find_all("tr")

siw = heading_elements[0].get_text() + '\n' + heading_elements_4[1].get_text() + paragraph_elements[1].get_text()
for p in paragraph_elements[2:5]:
    siw+='\n' + p.get_text()

siw+='\n\n' + heading_elements_4[2].get_text() + '\n' + paragraph_elements[5].get_text() + '\n' + paragraph_elements[6].get_text() + ul_elements[34].get_text()
siw+= paragraph_elements[7].get_text() + '\n' + paragraph_elements[8].get_text() + ul_elements[35].get_text() + '\n' + heading_elements_4[3].get_text() + '\n' + paragraph_elements[9].get_text()
siw+= ul_elements[36].get_text() + '\n' + heading_elements[2].get_text()

siw+= '\n\n' + "Semestre 4, 15 semaines"
for tr in tr_elements[20:39]:
    siw+= '\n' + tr.get_text().strip().replace('\n', ", ")

siw+='\n\n' + heading_elements[2].get_text() + '\n' + "Semestre 5, 15 semaines"
for tr in tr_elements[39:58]:
    siw+= '\n' + tr.get_text().strip().replace('\n', ", ")

siw+='\n\n' + "Semestre 6, 15 semaines"
for tr in tr_elements[58:77]:
    siw+= '\n' + tr.get_text().strip().replace('\n', ", ")
    
docs.append({
    "url": url,
    "content": siw
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/specialite-intelligence-artificielle-et-sciences-de-donnees-iasd/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
heading_elements_4 = soup.find_all("h4")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")
ol_elements = soup.find_all("ol")
tr_elements = soup.find_all("tr")

iasd = heading_elements[0].get_text() + '\n' + heading_elements_4[1].get_text() + '\n' + paragraph_elements[2].get_text() + ol_elements[0].get_text()
iasd+='\n' + heading_elements_4[2].get_text() + '\n' + paragraph_elements[3].get_text() + ul_elements[35].get_text() + paragraph_elements[4].get_text() + '\n' + paragraph_elements[5].get_text()
iasd+=ul_elements[35].get_text() + '\n' + heading_elements_4[3].get_text() + '\n' + paragraph_elements[6].get_text() + ul_elements[36].get_text()

iasd+= '\n' + "Semestre 4, 15 semaines"
for tr in tr_elements[20:39]:
    iasd+= '\n' + tr.get_text().strip().replace('\n', ", ")

iasd+='\n\n' + heading_elements[2].get_text() + '\n' + "Semestre 5, 15 semaines"
for tr in tr_elements[39:58]:
    iasd+= '\n' + tr.get_text().strip().replace('\n', ", ")

iasd+='\n\n' + "Semestre 6, 15 semaines"
for tr in tr_elements[58:77]:
    iasd+= '\n' + tr.get_text().strip().replace('\n', ", ")
    
docs.append({
    "url": url,
    "content": iasd
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/specialite-cybersecurite-cys/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
heading_elements_4 = soup.find_all("h4")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")

cys = heading_elements[0].get_text() + '\n' + heading_elements_4[1].get_text() + '\n' + paragraph_elements[0].get_text() + ul_elements[34].get_text() + paragraph_elements[3].get_text()
cys+= '\n\n' + heading_elements_4[2].get_text() + '\n' + paragraph_elements[4].get_text() + ul_elements[35].get_text() + paragraph_elements[5].get_text() + ul_elements[36].get_text() + paragraph_elements[6].get_text() 
cys+='\n\n' + heading_elements_4[3].get_text() + '\n' + paragraph_elements[7].get_text() + '\n' + paragraph_elements[8].get_text() + ul_elements[37].get_text() + paragraph_elements[9].get_text() + '\n' + paragraph_elements[10].get_text()

docs.append({
    "url": url,
    "content": cys
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/master-complementaire/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
paragraph_elements = soup.find_all("p")

master = heading_elements[0].get_text()
for p in paragraph_elements[:3]:
    master+='\n' + p.get_text()

docs.append({
    "url": url,
    "content": master
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/departement-classe-preparatoire/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
paragraph_elements = soup.find_all("p")

prepa = heading_elements[0].get_text()
prepa+='\n' + paragraph_elements[0].get_text()

docs.append({
    "url": url,
    "content": prepa
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/departement-second-cycle/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")

sup = heading_elements[0].get_text()
sup+='\n' + paragraph_elements[0].get_text() + '\n' + paragraph_elements[1].get_text()
sup+='\n\n' + heading_elements[1].get_text() + ul_elements[34].get_text()

sup = """
Département Second Cycle

L’accès au premier semestre de la première année du second cycle est réservé aux étudiants ayant validé avec succès les deux années du tronc commun dans les classes préparatoires.
Les étudiants les mieux classés sont admis directement. Les autres candidats peuvent accéder à la formation par le biais du concours national d’entrée aux grandes écoles, dans la limite des capacités pédagogiques de l’établissement et conformément à la réglementation en vigueur.

Soucieuse d’assurer une parfaite adéquation entre les compétences acquises en formation et les attentes du monde socioéconomique, l’École Supérieure en Informatique de Sidi Bel Abbès élabore ses programmes pédagogiques en concertation avec les acteurs institutionnels et industriels. Cette approche garantit une formation professionnalisante, orientée vers l’opérationnalité immédiate des futurs ingénieurs.

Spécialités proposées

1. Systèmes d’Information et Web
Cette option offre un profil de connaissances larges et des compétences affirmées dans le domaine informatique, permettant la prise en charge et/ou la participation à tout projet d’analyse, de conception et de mise en œuvre de systèmes d’information au sein des entreprises et des administrations.

2. Ingénierie des Systèmes Informatiques
Elle fournit aux futurs ingénieurs des notions fondamentales sur les systèmes informatiques et leurs applications dans différents domaines : réseaux informatiques, systèmes temps réel, systèmes embarqués, etc.
Les diplômés seront capables de concevoir, développer et exploiter des infrastructures informatiques complètes.

3. Intelligence Artificielle et Sciences de Données
L’objectif est de former des ingénieurs de haut niveau spécialisés en intelligence artificielle et en science des données, en lien avec la recherche et l’industrie.
Les compétences développées incluent :

La conception et mise en œuvre de systèmes basés sur l’IA.

Le développement de solutions Big Data à l’aide des techniques récentes (IA, Machine Learning, architectures distribuées).

Le stockage, l’extraction, l’analyse et l’exploitation de grands volumes de données pour des usages variés : aide à la décision, optimisation, prédiction, etc.

4. Cybersécurité (CyS)
Cette option vise à doter les étudiants de connaissances solides et de compétences pointues en sécurité des systèmes d’information.
Les enseignements portent notamment sur :

La sécurité des réseaux et applications,

La cryptographie avancée,

Le pentesting,

La gestion des incidents,

La sécurité dans les environnements cloud et IoT.
Elle forme des ingénieurs capables de concevoir, déployer et maintenir des architectures informatiques sécurisées, adaptées aux besoins des entreprises, institutions et environnements critiques.

Master complémentaire

Les étudiants en troisième année du second cycle désirant obtenir le diplôme de Master doivent suivre des enseignements complémentaires d’initiation à la recherche scientifique.
L’objectif est de les initier au monde de la recherche, y compris la formation doctorale.
"""

docs.append({
    "url": url,
    "content": sup
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/formation-continue/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")
heading_elements = soup.find_all("h3")
paragraph_elements = soup.find_all("p")

formation = heading_elements[0].get_text()
for p in paragraph_elements[:3]:
    formation+= '\n' + p.get_text()

docs.append({
    "url": url,
    "content": formation
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/formation/formation-texte-reglementaire/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml") 
heading_elements = soup.find_all("h3")
ul_elements = soup.find_all("ul")
a_elements = soup.find_all("a")

links = [a.get("href") for a in a_elements[156:178]]
text = heading_elements[0].get_text()
text+=ul_elements[34].get_text() + '\n' + heading_elements[1].get_text() + ul_elements[35].get_text() + '\n' + heading_elements[2].get_text() + ul_elements[36].get_text() + '\n' + heading_elements[3].get_text() + ul_elements[37].get_text() + '\n' + heading_elements[4].get_text() + ul_elements[38].get_text()

for link in links:
    text = text.replace("Télécharger", link, 1)
    
docs.append({
    "url": url,
    "content": text
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/post-graduation-recherche-missions/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")
heading_elements = soup.find_all("h3")
span_elements = soup.find_all("span")


recherche = "Post graduation et recherche" + '\n' + heading_elements[0].get_text() + '\n' + heading_elements[1].get_text()
for span in span_elements[6:27]:
    recherche+= '\n' + span.get_text()

recherche += '\n\n' + "MALKI Mimoun, Professeur, m.malki@esi-sba.dz, Directeur adjoint chargé de la formation doctorale de la recherche scientifique et du développement technologique, de l’innovation et de la promotion de l’entreprenariat"

docs.append({
    "url": url,
    "content": recherche
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/doctorat/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")
heading_elements = soup.find_all("h3")
ul_elements = soup.find_all("ul")
ol_elements = soup.find_all("ol")
a_elements = soup.find_all("a")

links = [a.get("href") for a in a_elements[154:162]]

doctorat = heading_elements[0].get_text() + '\n' + heading_elements[1].get_text() + ul_elements[34].get_text() + '\n' + "Dossier d'inscription" + ol_elements[0].get_text()
doctorat+=heading_elements[2].get_text() + '\n\n' + heading_elements[3].get_text() + ul_elements[35].get_text() + heading_elements[4].get_text() + ol_elements[1].get_text() + heading_elements[5].get_text() + ol_elements[2].get_text()
doctorat+=heading_elements[6].get_text()

for link in links:
    if not link.startswith("https://www.esi-sba.dz"):
        link = "https://www.esi-sba.dz" + link
    doctorat = doctorat.replace("Télécharger", link, 1)

docs.append({
    "url": url,
    "content": doctorat
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/ingenierie-des-systemes-dinformation-et-de-connaissances-et-aide-a-la-decision-isicad/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
heading_elements_4 = soup.find_all("h4")
ul_elements = soup.find_all("ul")
paragraph_elements = soup.find_all("p")
a_elements = soup.find_all("a")

link = "https://www.esi-sba.dz" + a_elements[154].get("href")

doc = "Spécialités Doctorat" + '\n' + heading_elements[0].get_text() + '\n' + heading_elements_4[0].get_text() + '\n' + paragraph_elements[2].get_text()
doc+='\n' + heading_elements_4[1].get_text() + '\n' + paragraph_elements[4].get_text() + ul_elements[34].get_text() + '\n' + paragraph_elements[5].get_text()
doc+='\n' + paragraph_elements[6].get_text() + '\n' + paragraph_elements[7].get_text() + ul_elements[35].get_text()
doc+=paragraph_elements[7].get_text() + ul_elements[36].get_text() + '\n' + heading_elements_4[2].get_text() + '\n' + paragraph_elements[10].get_text()
doc+=heading_elements_4[3].get_text() + ul_elements[37].get_text()

doc = doc.replace("Télécharger", link, 1)

docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/intelligence-artificielle-et-ses-applications-iaa/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
heading_elements_4 = soup.find_all("h4")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")

doc = "Doctorat" + '\n' + heading_elements[0].get_text() + '\n' + heading_elements_4[0].get_text() + '\n' + paragraph_elements[2].get_text() + '\n' + heading_elements_4[1].get_text()

for p in paragraph_elements[3:8]:
    doc+='\n' + p.get_text()

doc+='\n\n' + heading_elements_4[2].get_text() + ul_elements[34].get_text() + '\n' + heading_elements_4[3].get_text() + '\n' + paragraph_elements[10].get_text()

doc = doc.replace("Télécharger", "https://www.esi-sba.dz/fr/wp-content/uploads/2025/05/description-formation-doctorale_IA-1.pdf")

for d in docs:
    if d["url"] == url:
        d["content"] = doc
        print("done")
        
# docs.append({
#    "url": url,   
#    "content": doc
#})
# Out:
# done

# %%
url = "https://www.esi-sba.dz/fr/index.php/reseaux-et-securite/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
heading_elements_4 = soup.find_all("h4")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")

doc = "Doctorat" + '\n' + heading_elements[0].get_text() + '\n' + heading_elements_4[0].get_text() + '\n' + paragraph_elements[2].get_text() + '\n' + heading_elements_4[1].get_text()

for p in paragraph_elements[3:8]:
    doc+='\n' + p.get_text()

doc+='\n' + heading_elements_4[2].get_text() + '\n' + paragraph_elements[8].get_text() + '\n' + heading_elements_4[3].get_text() + '\n' + paragraph_elements[9].get_text()

doc = doc.replace("Télécharger", "https://www.esi-sba.dz/fr/wp-content/uploads/2025/05/description-formation-doctorale_Securite.pdf", 1)

for d in docs:
    if d["url"] == url:
        d["content"] = doc
        print("done")
        
# docs.append({
#    "url": url,  # <<<<<--------- HNA
#    "content": doc
#})
# Out:
# done

# %%
url = "https://www.esi-sba.dz/fr/index.php/presentation-labri/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
paragraph_elements = soup.find_all("p")

doc = "Laboratoire Labri" + '\n' + heading_elements[0].get_text() + '\n' + paragraph_elements[0].get_text()

docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/isewed/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
paragraph_elements = soup.find_all("p")

doc = "Equipe de recherche, labortoire labri" + '\n' + heading_elements[0].get_text() + '\n'
doc+="""
Mots-clés :
Integration and Interoperability of Information Systems, Knowledge Graphs, Ontology Engineering, Reverse Engineering, Semantic IoT, Mutli-agent Systems, Web Intelligence
"""

doc+=heading_elements[1].get_text() + '\n' + paragraph_elements[0].get_text() + '\n' + heading_elements[2].get_text()
doc+='\n' + """
Nom,Prenom,Grade,Email
MALKI,Mimoun,Professeur,m.malki@esi-sba.dz
BENDAOUD,Paycal,MCA,f.bendaoud@esi-sba.dz
BENCHERIF,Kheyra,MCA,k.bencherif@esi-sba.dz
TOUMOUH,Adil,MCA,toumouh@gmail.com
AWAD,Samir,MCB,s.awad@esi-sba.dz
LEHIRECHE,Nesrinne,MCB,n.lehireche@esi-sba.dz
ZAHAF,Ahmed,MCB,zhmida@gmail.com
FELLAH,Aissa,MCB,ammfellah@yahoo.fr
REGUIEG YSSAAD,Sadek,MAA,s.reguiegyssaad@esi-sba.dz
"""

doc+=heading_elements[3].get_text()
doc+="""
Nom,Prenom,Intitulé de la thèse,Encadreur
TOU,Mohamed,"Le cloud computing pour assurer l’accessibilité aux services et la continuité des affaires économiques","Toumouh Adil & Malki Mimoun"
BOUDIAB,Wassim,"Equilibrage de charges pour les Micro-services dans un environnement IoT","Malki Mimoun & Malki Abdelhamid"
BERKANI,Meriem,"intelligent Multi-Agent based IoT systems","Malki Mimoun & Bencherif Keyra"
MEKKAOUI,Ayoub,"Query Optimization Over Fog Computing Using Machine Learning Techniques","Malki Abdelhamid"
BOUKAZOU LA,Nassim,"Management des données à base de Micro-services Sémantiques dans un Environnement IoT","Malki Mimoun & Malki Abdelhamid"
"""

docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/dase/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")

doc = heading_elements[0].get_text() + '\n' + "Responsable de l’équipe Dr. Amar Bensaber Djamel"
doc+="""
Mots-clés :
Gestion des données, ingénierie dirigée par les modèles, métamodélisation, qualité de logiciel, linked-data, Big Data, Big data analysis, Semantic Web, Semantic metadata, apprentissage automatique, deep learning, Internet des objets, stream processing, ontologies, Parallel Processing.
"""


doc+= paragraph_elements[0].get_text() + ul_elements[34].get_text() + paragraph_elements[1].get_text() + '\n\n' + heading_elements[1].get_text() + ul_elements[35].get_text()
doc+='\n' + heading_elements[2].get_text()

doc+= """
Nom,Prenom,Grade,Email
AMAR BENSABER,Djamel,Professeur,d.amarbensaber@esi-sba.dz
KESKES,Nabil,Professeur,n.keskes@esi-sba.dz
SAIDI,Imene,MCB,i.saidi@esi-sba.dz
SMAHAT,Mohamed,MAA,m.smahat@esi-sba.dz
SIMOHAMED,Nasreddine,MAA,n.simohamed@esi-sba.dz
BADSI,Hichem,MCB,h.badsi@esi-sba.dz
BELFEDHAL,AlaaEddine,MCB,a.belfedhal@esi-sba.dz
CHAIB,Slimane,MAB,s.chaib@esi-sba.dz
"""

doc+='\n' + heading_elements[3].get_text()
doc+="""
Nom,Prenom,Grade,Email,Intitulé de la thèse,Encadreur
TROULI,Amina,,,,a.taouli@esi-sba.dz
GRABA,Djober Dalila,,,,d.graba@esi-sba.dz
ATTAOUI,Mohamed Walid,,,,m.attaoui@esi-sba.dz
AZAIZ,Mohamed Amine,,,,m.azaiz@esi-sba.dz
HAMDADOU,Djamel,,,,
BENZOHRA,Abdelkader,,,,
CHENINE,Abdelkader,,,,
GUELLIL,Zouaoui,,,,
DJEBOURI,Djamila,,,,
"""

docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/soc/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
ul_elements = soup.find_all("ul")

doc = heading_elements[0].get_text() + '\n' + "Responsable de l’équipe Pr. BENSLIMANE Sidi Mohamed"
doc +="""
Mots-clés :
Architecture orientée Service, Réingénierie des applications Web, Ingénierie des ontologies, Web Sémantique, Cloud Computing, Social Computing, Données liées, Confidentialité, Processus métiers, MDA, Systèmes de recommandation, IHM, Énergies renouvelables, Internet des objets, Smart Services, Business Intelligence, Knowledge Graph, Smart Healthcare and Farming, Artificial intelligence, Human-Swarm Interaction, Multimodal Interaction, robotic swarms.
"""

doc+='\n' + heading_elements[1].get_text() + ul_elements[34].get_text() + '\n' + heading_elements[2].get_text()
doc+="""
Nom,Prenom,Grade,Email
BENSLIMANE,Sidi Mohammed,Professeur,s.benslimane@esi-sba.dz
ELOUALI,Nadia,MCA,n.elouali@esi-sba.dz
KHALDI,Belkacem,MCA,b.khaldi@esi-sba.dz
MAHAMMED,Nadir Bachir,MCA,n.mahammed@esi-sba.dz
MALKI,Abdelhamid,MCA,a.malki@esi-sba.dz
AMRANE,Abdelkader,MCB,a.amrane@esi-sba.dz
BEDJAOUI,Mohammed,MCB,m.bedjaoui@esi-sba.dz
BEZZAOUCHA,Fatima Souad,MCB,fs.bezzaoucha@esi-sba.dz
BOUSMAHA,Rabab,MCB,r.bousmaha@esi-sba.dz
DIF,Nassima,MCB,n.dif@esi-sba.dz
KHALDI,Miloud,MCB,m.khaldi@esi-sba.dz
KLOUCHE,Badia,MCB,b.klouche@esi-sba.dz
NAOUM,Hanae,MCB,h.naoum@esi-sba.dz
SERHANE,Oussama,MCB,o.serhane@esi-sba.dz
"""

doc+=heading_elements[3].get_text()
doc+="""
Nom,Prenom,Grade,Email
KHALFI,Mohamed Fethi,MCA,fethi_khalfi@yahoo.fr
BOUDAA,Boudjemaa,MCA,boudaa.boudjemaa@gmail.com
"""

doc+='\n'+heading_elements[4].get_text()
doc+="""
Nom,Prenom,Intitulé de la thèse,Encadreur,Email
BENABBOU,Fatna Bent Ennebi,"Human-Swarm Interactions for People with Special Needs","Pr. BENSLIMANE Sidi Mohamed Dr. KHALDI Belkacem",f.benabbou@esi-sba.dz
MEFTAII,Salima,"Vers des interfaces homme-machine intelligentes pour l'aide à la décision","Pr. BENSLIMANE Sidi Mohamed Dr. SAHNOUN M'hammed",s.meftah@esi-sba.dz
BENKEMCHI,Oussama,"Allocation des ressources dans le cloud et edge computing avec l'apprentissage par renforcement","Pr. BENSLIMANE Sidi Mohamed Dr. AMRANE Abdelkader",o.benkemchi@esi-sba.dz
IIOUA,Kheireddine,"Building Graph Database IoT Based-Solution in Healthcare","Pr. BENSLIMANE Sidi Mohamed",k.houa@esi-sba.dz
BOUSBA,Fadia Nouna,"La multimodalité dans le contexte de l'internet des objets","Pr. BENSLIMANE Sidi Mohamed Dr. ELOUALI Nadia",f.bousba@esi-sba.dz
LARBI,Bochra,"Towards A moderate Persuasion For Human-Machine Interfaces","Dr. ELOUALI Nadia",b.larbi@esi-sba.dz
"""

docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/cisco/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")

doc = heading_elements[0].get_text() + '\n' + "Responsable de l’équipe Pr. RAHMOUN Abdellatif"
doc+="""
Mots-clés :
Soft computing, Artificial Intelligence, swarm intelligence, Machine Learning, Embedded systems, Smart Services, Internet of Things, deep learning, smart city, E-health.
"""

doc+=heading_elements[1].get_text() + '\n' + paragraph_elements[0].get_text() + ul_elements[34].get_text() + '\n' + heading_elements[2].get_text()
doc+=""" 
Nom,Prenom,Grade,Email
RAHMOUN,Abdelatif,Professeur,a.rahmoun@esi-sba.dz
ELARBIBOUDIHIR,Mohamed,MCA,m.elarbiboudihir@esi-sba.dz
LEBBAH,Fatima Zohra,MCB,fz_lebbah@yahoo.fr
Bensenane,Hamdane,MCB,h.bensenane@esi-sba.dz
Kazi Tani,Yacine,MCB,y.Kazi@esi-sba.dz
Bekkouche,Mohammed,MCB,m.bekkouche@esi-sba.dz
MOSTEFAOUI,Mohammed,MCA,m.mosteraoui@esi-sba.dz
"""

doc+='\n' + heading_elements[3].get_text()
doc+="""
Nom,Prenom,Intitulé de la thèse,Encadreur,Email
BAIDAR,Lotfi,,,1.baidar@esi-sba.dz
ABERKANE,Sabrina,,,s.aberkane@esi-sba.dz
ABIB,Mohamed,,,m.abib@esi-sba.dz
ZERROUKI,Kada,,,
Belferd,Acher,,,a.belferd@esi-sba.dz
Abib,Réda,,,r.abib@esi-sba.dz
Mouilah,Chikh,,cheikh.mouilah@univ-sba.dz Univ.Djilali Lyabès,
Mihoubi,Miloud,,mil.mihoubi@gmail.com Université de Tiaret,
Hocine,Saadi,,saadi@cerist.dz CERIST, Research Center Algiers,
Aberkane,Sabrina,,,s.aberkane@esi-sba.dz
DEMRI,Mohammed,,demri.med@gmail.com Université d'Adrar,
"""

doc+=heading_elements[4].get_text()
doc+="""
Nom,Prenom,Grade,Email
Mokhtaria,Barnoussi,MCB,mokhtaria.barnoussi@yahoo.fr
"""
docs.append({
    "url": url,
    "content": doc
})

# %%
doc = """
Page Google Scholar de l'école: https://scholar.google.com/citations?hl=fr&view_op=list_works&gmla=AJsN-F5PYNgbNP_hD12_GjQUVQyGpxQxJj7VB2lxOY0mo5tzzvtWsII1vEWsjafY73Y61MSNA_cDLvrdyHhpMjEs2SI-6HcRfI8JPmorSxynuTz2O9RwrfM&user=Qc9gr5IAAAAJ
"""

docs.append({
    "url": None,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/polycopie/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")
a_elements = soup.find_all("a")

links = [a.get("href") for a in a_elements]

doc = "Post graduation et recherche" + '\n' + heading_elements[0].get_text() + '\n' + paragraph_elements[0].get_text() + '\n' + paragraph_elements[1].get_text() + '\n' + paragraph_elements[2].get_text()
doc+=ul_elements[34].get_text() + paragraph_elements[3].get_text() + ul_elements[35].get_text()

doc+=paragraph_elements[4].get_text() + '\n' + paragraph_elements[5].get_text()

for link in links:
    doc = doc.replace("Télécharger", link, 1)
    
docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/habilitation/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")
a_elements = soup.find_all("a")

doc = "Post graduation et recherche"
doc = heading_elements[0].get_text() + '\n' + paragraph_elements[0].get_text()
doc = doc.replace("ici", "/fr/wp-content/uploads/2021/02/F2021008.pdf")
doc+='\n' + paragraph_elements[1].get_text()
doc = doc.replace("Télécharger", "/fr/wp-content/uploads/2020/12/Arrete-n°883-du-21-11-2020-modifiant-et-completant-larrete-n°750-du-12-10-2020.pdf", 1)
doc = doc.replace("Télécharger", "/fr/wp-content/uploads/2020/12/ANNEXE-20-883-ESI-Sidi-Bel-Abbes.pdf", 1) + '\n' + heading_elements[1].get_text()
doc+=paragraph_elements[2].get_text() + '\n' + paragraph_elements[3].get_text()

doc = doc.replace("AR", "https://www.esi-sba.dz/fr/wp-content/uploads/2021/10/Arrete-n°804-du-14-juil-2021_Habilitation-universitaire_Ar.pdf", 1)
doc = doc.replace("FR", "https://www.esi-sba.dz/fr/wp-content/uploads/2021/10/Arrete-n°804-du-14-juil-2021_Habilitation-universitaire_Fr.pdf", 1)
doc = doc.replace("AR", "https://www.esi-sba.dz/fr/wp-content/uploads/2021/10/decres-21-50-28-01-2021-modalite-habilitation-ar.pdf", 1)
doc = doc.replace("FR", "https://www.esi-sba.dz/fr/wp-content/uploads/2021/10/decres-21-50-28-01-2021-modalite-habilitation-fr.pdf", 1) + '\n' + heading_elements[2].get_text()
doc+='\n' + paragraph_elements[4].get_text() + '\n' + "https://www.esi-sba.dz/fr/wp-content/uploads/2021/10/Guide_de_procedures_HU_Fr.pdf"
doc+='\n' + heading_elements[3].get_text()

for p in paragraph_elements[5:9]:
    doc+='\n' + p.get_text()

doc+=heading_elements[4].get_text() + '\n' + paragraph_elements[9].get_text() + '\n' + "https://youtu.be/zxYWPUpABq0"

docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/post-graduation-recherche-texte-reglementaire/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
ul_elements = soup.find_all("ul")
a_elements = soup.find_all("a")

links = [a.get("href") for a in a_elements]

doc = "Post graduation et doctorat" + '\n' + heading_elements[0].get_text() + ul_elements[34].get_text()

for link in links:
    doc = doc.replace("Télécharger", link, 1)
    
docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/cooperations-missions/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
ul_elements = soup.find_all("ul")
paragraph_elements = soup.find_all("p")

doc = "Coopération" + '\n' + heading_elements[0].get_text()
doc+='\n' + paragraph_elements[0].get_text() + '\n' + paragraph_elements[1].get_text()
doc+=ul_elements[35].get_text() + '\n\n' + heading_elements[1].get_text() + '\n' + "Maître de Conférences B" + " " + "m.bedjaoui@esi-sba.dz"
doc+='\n' + paragraph_elements[2].get_text() + '\n\n' + heading_elements[2].get_text() + '\n' + paragraph_elements[3].get_text() + '\n' + ul_elements[36].get_text()
doc+=paragraph_elements[4].get_text() + '\n' + ul_elements[37].get_text()

docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/partenariat/partenariat-academique/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
heading_elements_4 = soup.find_all("h4")
ul_elements = soup.find_all("ul")
paragraph_elements = soup.find_all("p")

doc = heading_elements[0].get_text()
doc+='\n' + """
Signature d’une convention cadre de coopération entre l’ESI-SBA et l’ENPO
"""
doc+=heading_elements_4[0].get_text() + ul_elements[34].get_text()

doc+='\n' + """
Accord cadre entre l'ESI-SBA et l'école d'ingenieurs
"""
doc+= heading_elements_4[1].get_text() + ul_elements[35].get_text()
doc+= """
Accord cadre entre l'ESI-SBA et l'Institut Supérieur de l’Aéronautique et de l’Espace
""" + heading_elements_4[2].get_text() + ul_elements[36].get_text()

doc+='\n' + """
Accord cadre entre l'ESI-SBA et l'université de granada
""" + heading_elements_4[3].get_text() + ul_elements[37].get_text()

doc+='\n' + """
Accord cadre entre l'ESI-SBA et l'université d'istanbul
""" + heading_elements_4[4].get_text() + ul_elements[38].get_text()

doc+='\n' + """
Accord cadre entre l'ESI-SBA et l’École Nationale d’Ingénieurs de Tunis
""" + heading_elements_4[5].get_text() + ul_elements[39].get_text()

doc+='\n' + """ 
Adhesion aux services de AWS Educate
"""

doc+='\n' + """
Réseau Mixte d'Écoles
""" + heading_elements_4[6].get_text() + ul_elements[40].get_text()

doc+='\n' + """
Bourse PROFAS B+ Thèse en cotutelle
""" + heading_elements_4[7].get_text() + ul_elements[41].get_text()

doc+='\n' + """
Bourses d’Excellence RME
""" + heading_elements_4[8].get_text() + ul_elements[42].get_text()

doc+='\n' + """
Huawei
""" + heading_elements_4[9].get_text() + ul_elements[43].get_text()

doc+="\n" + "ADHESION GOOGLE APPS FOR EDUCATION"

doc+='\n' + """
Université Sorbonne Paris Nord
""" + heading_elements_4[10].get_text() + ul_elements[44].get_text()

doc+='\n' + """
Université Paris 8
""" + heading_elements_4[11].get_text() + ul_elements[45].get_text()


doc+='\n' + """
Institut polytechnique de Grenoble
""" + heading_elements_4[12].get_text() + ul_elements[46].get_text()

docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/partenariat/partenariat-professionnel/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
heading_elements_4 = soup.find_all("h4")
ul_elements = soup.find_all("ul")
paragraph_elements = soup.find_all("p")
span_elements = soup.find_all("span")

doc = heading_elements[0].get_text() + '\n' + "Signature d'un accord cadre de partenariat entre ESI de Sidi Bel Abbes et l'ENIE"
doc+='\n' + heading_elements_4[0].get_text() + ul_elements[34].get_text()

doc+= '\n' + "Signature d'un accord cadre de partenariat entre ESI de Sidi Bel Abbes et CNAC"
doc+='\n' + heading_elements_4[1].get_text() + ul_elements[35].get_text()

doc+= '\n' + "Signature d'un accord cadre de partenariat entre ESI de Sidi Bel Abbes et ALGERIE TELECOM"
doc+='\n' + heading_elements_4[2].get_text() + ul_elements[36].get_text()

doc+= '\n' + "Signature d'un accord cadre de partenariat entre ESI de Sidi Bel Abbes et l'ANVREDET"
doc+='\n' + heading_elements_4[3].get_text() + ul_elements[37].get_text()

doc+= '\n' + "Signature d'une convention entre l'ESI de Sidi-Bel-Abbès et l'ANPT"
doc+='\n' + heading_elements_4[4].get_text() + ul_elements[38].get_text()

doc+= '\n' + "Un Accord cadre de partenariat signé entre l'ESI-SBA et le Groupe des Sociétés HASNAOUI"
doc+='\n' + heading_elements_4[5].get_text() + ul_elements[39].get_text()

doc+= '\n' + "Un Accord cadre de partenariat a été signé entre l'ESI de Sidi Bel Abbes, et ATM MOBILIS ALGERIE."
doc+='\n' + heading_elements_4[6].get_text() + ul_elements[40].get_text()

doc+= '\n' + "Une convention cadre de partenariat vient d'être signée entre l'ESI de Sidi Bel Abbes, et l’agence nationale de soutien à l’emploi des jeunes (ANSEJ) de Sidi Bel Abbes."
doc+='\n' + heading_elements_4[7].get_text() + ul_elements[41].get_text()

doc+= '\n' + "Un Accord cadre de partenariat a été signé entre l'ESI de Sidi Bel Abbes, et le groupe CHIALI."
doc+='\n' + heading_elements_4[8].get_text() + ul_elements[42].get_text()

doc+= '\n' + "Un Accord cadre de partenariat a été signé entre l'ESI de Sidi Bel Abbes, et CITAL SPA."
doc+='\n' + heading_elements_4[9].get_text() + ul_elements[43].get_text()

doc+= '\n' + "Un Accord cadre de partenariat a été signé entre l'ESI de Sidi Bel Abbes, et la Société El Djazair Information Technology (ELIT) Spa, filiale du groupe SONELGAZ."
doc+='\n' + heading_elements_4[10].get_text() + ul_elements[44].get_text()

doc+= '\n' + "Signature d’un Accord Cadre entre l’ESI-SBA et le Groupe Condor"
doc+='\n' + heading_elements_4[11].get_text() + ul_elements[45].get_text()

doc+= '\n' + "Signature d'une convention entre l'ESI de Sidi-Bel-Abbès et KUMA Consulting & Facilities"
doc+='\n' + heading_elements_4[12].get_text() + ul_elements[46].get_text()

doc+= '\n' + "Signature d'un accord cadre entre l'ESI de Sidi-Bel-Abbès et La Confédération Générale Des Entreprise Algériennes (CGEA) LES AXES DE COLLABORATION S’INSCRIVENT, ENTRE AUTRES, DANS LES DOMAINES SUIVANTS :"
doc+='\n' + heading_elements_4[13].get_text() + ul_elements[47].get_text()


docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/cooperations-texte-reglementaire/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
heading_elements_4 = soup.find_all("h4")
ul_elements = soup.find_all("ul")
paragraph_elements = soup.find_all("p")
span_elements = soup.find_all("span")
a_elements = soup.find_all("a")

links = [a.get("href") for a in a_elements]
doc = 'Coopération' + '\n' + heading_elements[0].get_text() + ul_elements[34].get_text()

for link in links:
    doc = doc.replace("Télécharger", link, 1)
    
docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/bacheliers/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
heading_elements_4 = soup.find_all("h4")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")

doc = "Vie Estudiantine" + '\n' + heading_elements[0].get_text() + '\n' + heading_elements_4[1].get_text()
doc+=paragraph_elements[8].get_text() + '\n' + paragraph_elements[9].get_text() + '\n' + paragraph_elements[10].get_text() + '\n' + paragraph_elements[11].get_text()
doc+='\n\n' + heading_elements_4[2].get_text()

for p in paragraph_elements[12:23]:
    doc+='\n' + p.get_text()

doc+='\n\n' + heading_elements_4[3].get_text() + ul_elements[35].get_text()

doc+='\n\n' + heading_elements_4[4].get_text()
for p in paragraph_elements[23:26]:
    doc+='\n' + p.get_text()

doc+='\n\n' + heading_elements_4[5].get_text()
for p in paragraph_elements[26:30]:
    doc+='\n' + p.get_text()

doc+='\n\n' + heading_elements_4[6].get_text()
for p in paragraph_elements[30:32]:
    doc+='\n' + p.get_text()

doc+='\n\n' + heading_elements_4[7].get_text() + '\n' + paragraph_elements[32].get_text() + ul_elements[36].get_text()

docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/inscriptions-reinscription-2024/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h1")
heading_elements_4 = soup.find_all("h4")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")

doc = "Vie Estudiantine" + '\n' + heading_elements[0].get_text() + '\n' + "Calendrier des préinscriptions et inscription définitives"

doc+="""
Période,Activité,Dates,Détails/Notes
Information générale,Journées Portes ouvertes,Du 16 au 23 Juillet 2025,Mode virtuel
Information générale,Visite virtuelle à l'ESI SBA,,https://tour.esi-sba.dz
Période 1,Préinscription en ligne,Du 22 au 26 Juillet 2025,
Période 1,Confirmation des préinscriptions en ligne,Du 27 au 29 juillet 2025,
Période 1,Proclamation des résultats des affectations,5 Août 2025 au soir,
Période 2,Inscription définitives en ligne,Du 10 au 15 Août 2025,Sur PROGRES. Ouverture de la plateforme de paiement de frais d'inscription en ligne (selon la date du rendez-vous précisée dans l'attestation d'orientation). L'inscription devient définitive dès le paiement des frais d'inscription en ligne.
Période 3,Préinscription, orientation et inscription définitive en ligne,Du 06 au 08 Août 2025,Pour les candidats n'ayant obtenu aucun de leurs choix (cas des choix 0). Introduction des nouveaux vœux (dans le respect des moyennes minimales d'accès)
Période 3,Proclamation des résultats,11 Août 2025 au soir,
Période 3,Paiement des frais d'inscription en ligne,Du 13 au 15 Août 2025,L'inscription devient définitive une fois les frais d'inscription réglés.
Période 4,Dépôt des demandes,Du 19 au 23 Août 2025,Traitement des cas particuliers par les EES sur la plateforme PROGRES
Période 4,Proclamation des résultats et inscription définitive,Du 24 au 25 Août 2025,
Période 4,L'inscription devient définitive une fois les frais réglés,26 Août 2025,
Période 5,Cours d'anglais en ligne,Du 26 Juillet au 25 Septembre 2025,
"""

docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/hebergement-restauration/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h3")
heading_elements_4 = soup.find_all("h4")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")

doc = "Vie Estudiantine" + '\n' + heading_elements[0].get_text() + '\n' + heading_elements[1].get_text() + '\n' + heading_elements[2].get_text() + " " + "https://tour.panoee.net/6685ff7a1dd7b1b9005ca0db/6685ffe91dd7b1534e5ca0e8"
doc+='\n' + heading_elements[3].get_text() + '\n' + heading_elements[4].get_text() + " " + "https://tour.panoee.net/66867922ec50130a6e6c3a6b/668679571dd7b180da5ca723"
doc+='\n' + heading_elements[5].get_text() + '\n' + heading_elements[6].get_text() + " " + "https://tour.panoee.net/66860b721dd7b154995ca137/66860dc51dd7b1fa6c5ca15f"

docs.append({
    "url": url,
    "content": doc
})

# %%
url = "https://www.esi-sba.dz/fr/index.php/alphabit/"
response = requests.get(url)

soup = BeautifulSoup(response.content, "lxml")

heading_elements = soup.find_all("h1")
heading_elements_3 = soup.find_all("h3")
heading_elements_4 = soup.find_all("h4")
paragraph_elements = soup.find_all("p")
ul_elements = soup.find_all("ul")

doc = "Club scientifique" + '\n' + heading_elements[0].get_text() + '\n' + paragraph_elements[0].get_text() + '\n' + heading_elements_3[0].get_text()
doc+='\n' + paragraph_elements[1].get_text() + '\n' + paragraph_elements[2].get_text() + '\n' + heading_elements_3[1].get_text() + '\n' + paragraph_elements[3].get_text()
doc+='\n' + heading_elements_3[2].get_text() + '\n' + paragraph_elements[4].get_text() + '\n' + heading_elements_3[3].get_text() + '\n' + paragraph_elements[5].get_text()
doc+='\n' + heading_elements_3[4].get_text() + '\n' + paragraph_elements[6].get_text() + '\n' + heading_elements_3[5].get_text() + '\n' + paragraph_elements[7].get_text()
doc+='\n' + heading_elements_3[5].get_text() + '\n' + paragraph_elements[7].get_text()
doc+="""
Liste des fondateurs
Ali Taleb Aymen
Zemour Mohamed Oussama
Bounoua Nadir
Charmat abderraouf
Sidi-Mohamed Moulay Sliman
Mohamed Abdelillah Belabbes
Allahoum Nadjia
Ben Abdallah Omar
Merzoug Mohamed
Cherrad Charaf
Achraf Nasser eddine belfered
Ben Abdallah Omar
Actuels membres du Bureau :
Président : BELAID El Baraa
Vice-Président : DELLAA Abderrahmen
Membres :

    BEN BAIT Mohamed Seddik
    KENNOUCHE Abderrahmane
    MOKADDEM Sara
    BOUCHELAREM Lydia Houyem
    BENHIBA Fodhil

Coordonnées du club :

Email :
Téléphone : 0782763349

Facebook : https://www.facebook.com/profile.php?id=100089682379294

Instagram : https://www.instagram.com/alphabitclub/
"""

docs.append({
    "url": url,
    "content": doc
})

# %%
doc = """
Club Scientifique
INGENIUMS
Ingeniums est plus un foyer qu’un club pour ses membres. C’est une congrégation d’étudiants motivés et passionnés qui partagent des valeurs. Ce club a été créé pour se connecter les uns aux autres, apprendre, partager, et innover. C’est un environnement convivial qui vise la croissance collective par le partage de connaissance et la création d’un milieu positif et accueillant qui facilite l’intégration sociale, scolaire et professionnelle des étudiants. De plus, il offre une atmosphère saine pour découvrir la diversité culturelle dont se réjouit le club.

Historique

À la recherche de quelque chose de différent, de quelque chose de plus spécial et de valeurs réelles, un groupe d’amis dans leur dortoir a voulu créer un « groupe » plus tard un « club » qui se développerait et évoluerait pour devenir une grande famille où l’on peut trouver l’acceptation, la connaissance, le soutien et surtout “un foyer” où chacun peut atteindre son plein potentiel. Autrement dit, « INGENUIMS ».

En octobre 2017, le recrutement a commencé. dix-sept personnes, des étudiants de troisième et de deuxième année, se sont jointes pour faire partie du « club », avec des perspectives et des personnalités riches et différentes. Ce n’est qu’en novembre de la même année que le club est devenu officiel avec le plein soutien d’ESI-SBA.

Selon l’un des membres fondateurs, choisir un nom pour le club était:“ a brainstorming activity”.Pour eux, ce n’était pas seulement un nom, c’était la traduction de la famille, de l’amitié, de la communauté, du travail d’équipe, du travail acharné et de la joie . Tous ces principes, idéaux devait être   repris en un mot, et ainsi INGENUIMS il était.

Au début, la structure du club était simple: un président, un vice-président et un animateur d’événements. Le travail a été divisé entre les membres existants, cependant, la diversité des opinions et des perspectives a causé tant de défis néanmoins INGENIUMS a prouvé son efficacité à concurrir des difficultés.

Une fois que tout a été réglé et mis en place, les membres se sont retrouvés face à un nouveau défi « Ingeniums First Event », un événement qui non seulement les représente et leurs objectifs, mais aussi leur vision   d’un endroit  où la connaissance accompagne le plaisir. Ainsi, après quinze jours de planification et de discussions, « TALK DAY » est devenu le premier événement d’Ingeniums. Il a été organisé pour aider les étudiants de l’ESI-SBA à comprendre les choses liées à l’école et à l’informatique plus généralement en suivant le système de “question réponse “ où tous les membres ont contribué. À la fin de la journée, l’événement a été un succès et les membres étaient fiers de leur travail acharné. C’est alors qu’ils ont senti qu’ils appartenaient à quelque chose de spécial.

Les années passèrent, plus de souvenirs furent faits, plus d’amitiés se construisirent, plus d’événements ont été organisés et surtout, notre famille devint de plus en plus grande qu’auparavant. La structure du club a été changée en président, vice-président, SG, et cinq département :

    Département de Finance.
    Département de ressources humaines.
    Département de marketing.
    Learning community.
    Département de logistique.

L’un des grands événements d’Ingeniums était MLH en septembre 2018, Ingehack en 2018, journée Amazigh en janvier. Pour plus d’informations, veuillez consulter la liste des événements. Peu importe à quel point ces événements sont différents, les participants trouvent toujours la joie, la connaissance et étaient très satisfaits ce qui a rendu les membres et les organisateurs si fiers de faire partie de club.

Après tout, Ingeniums est Où nous créons notre propre infinité!  Rejoignez-nous et faites partie de cette famille.


YENNAYER

Cet événement est très spécial car en ce jour, les étudiants de l’esi sba de tous les 48 wilayas du pays ont la chance de célébrer leurs traditions et spécialement la nouvelle année TAMAZIGHT. On voit à l’occasion de YENNAYER toute l’école en mode traditionnel, allons des costumes jusqu’aux plats délicieux et la musique algérienne..

LINUX INSTALL PARTY

C’est un événement dédié plus pour les étudiants de la 1ère année de cycle préparatoire pour les aider à installer et configurer le système d’exploitation Linux sur leurs machines, car ils l’ont besoin en module de Système d’exploitation.
MLH:Local Hack Day

C’est un hackathon international de 12 heures qu’ingeniums prend la responsabilité de l’organiser chaque année, en assurant durant ce hackathon des Workshops de qualité pour les participants, et des prix symboliques pour les gagnants.

INGEHACK

C’est un hackathon de cybersécurité, qui dure tout au long d’un weekend, les participants passionnés auront la chance de résoudre des problèmes (CAPTURE THE FLAG).
TALK DAY

Une session dédiée pour accueillir les nouveaux bacheliers et répondre à leurs questions sur tout ce qui concerne les études à l’esi sba, qui est intéressant que les étudiants des autres années partagent leurs expériences et différents conseils.

SI Chess

Comme son nom l’indique, cet événement est un tournoi de jeux d’échecs (chess), ou les étudiants de l’école s’affrontent en exposant leurs talents magnifiques.
Actuels membres du Bureau :
Président : CHIKHAOUI Youcef Chihab Eddine
Vice-Président : ACHOURI Youcef Islem
 
Membres :

    HANNACHI Seif Errahmane
    KACIMI Nadjiba
    MEDJAHRI Mohammed Safouane
    MERZOUKA Younes Abdel Samade
    BELKACEM Khalid
    LAHILAH Mountassar Billah
    DENNAI Amro Abdellah
    BOUAMINE Houdaifa
    MIHI Badis Mohammed Ali

 
Facebook : https://www.facebook.com/ingeniums
"""

docs.append({
    "url": None,
    "content": doc
})

# %%
doc = "Vie estudiantine Réglement intérieur: https://www.esi-sba.dz/fr/wp-content/uploads/2021/10/reglement_interieur_ESI-SBA_2021.pdf"
docs.append({
    "url": None,
    "content": doc
})

# %%
print(len(docs))
# Out:
# 47

# %%
# Save the data as JSON file
import json

with open("./data/ESI-SBA.json", "w") as json_file:
    json.dump(docs, json_file, indent=4)

# %% [markdown]
# ### Chunking

# %%
# Apply chunking based on course parts
current_title = docs[0].page_content.split('\n')[0]
chunks = []
chunks.append(docs[0].page_content)
for doc in docs[1:]:
    if doc.page_content.split('\n')[0] == current_title:
        for line in doc.page_content.split('\n')[1:]:
            chunks[-1] += '\n' + line       
    else: 
        current_title = doc.page_content.split('\n')[0]
        chunks.append(doc.page_content)

# %%
# Apply sub-chunking for long chunks
from langchain.text_splitter import RecursiveCharacterTextSplitter

splitter = RecursiveCharacterTextSplitter(
    chunk_size=4000,
    chunk_overlap=40,
    separators=['\n\n', '\n', ' ', '']
)

for i, chunk in enumerate(chunks):
    if len(chunk.split()) > 1000:
        sub_chunks = splitter.split_text(chunk)
        chunks[i:i+1] = sub_chunks

# %%
print(chunks)
# Out:
# ['Democratic and Popular Republic of Algeria \nMinistry of Higher Education and Scientific Research \nHigher School of Computer Science, May 8, 1945, Sidi Bel Abbes  \n \nAcademic year: 2023-2024                                                                    Semester  1 \nPreparatory class 1                                                                                 Module: Computer Architecture 1 \n', 'Introduction \n \n\uf0d8The organization of any computer depends considerably on how it represents \ndata.  \n\uf0d8This chapter describes the various ways in which computers can store and \nmanipulate numbers and characters.  \n\uf0d8The ideas presented in the following sections form the basis for understanding \nthe organization and function of all types of digital systems. \n', 'Bit / Byte \n \n\uf0d8The most basic unit of information in a digital computer is called a bit, which is \na contraction of binary digit.  \n\uf0d8A bit has two numerical values: 0 and 1. \n\uf0d8In
# ...

# %% [markdown]
# ### Embedding

# %%
# Apply text-embedding-3-large from OpenAI
import os
from openai import OpenAI

openai_api_key = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key = openai_api_key)

response = client.embeddings.create(
    input="this is a test sentence",
    model = "text-embedding-3-large"
)

print(response.data[0].embedding)
# Out:
# [0.001314252964220941, 0.026127932593226433, -0.012435459531843662, 0.04970592260360718, 0.012992137111723423, -0.020489327609539032, -0.01737372949719429, 0.044246893376111984, -0.028408516198396683, 0.0028978660702705383, 0.017346791923046112, 0.04198426753282547, 0.0059169442392885685, -0.04277439042925835, 0.00901009701192379, 0.023488203063607216, -0.01863972097635269, 0.015999991446733475, -0.00799550674855709, -0.010855213738977909, 0.012974180281162262, -0.02738494798541069, -0.02291356958448887, 0.024475857615470886, 0.03151513636112213, 0.0024085284676402807, -0.008094272576272488, 0.025158237665891647, -0.020974176004529, -0.003317618975415826, 0.030024677515029907, 0.04148146137595177, 0.0036161597818136215, 0.018927039578557014, 0.038644202053546906, -0.02303927019238472, 0.02966552972793579, 0.02402692474424839, -0.004992141388356686, 0.008031421341001987, 0.047084152698516846, -0.01731087826192379, -0.045970797538757324, 0.023703692480921745, 0.00757799856364727, -0.00
# ...
